# %% [markdown]
# # addition
#
# > WITH a module description here

# %%
#| default_exp addition

# %%
#| hide

# %%
#| export
def say_hello(towards):
    "Say hello to somebody"
    return f'Hello {towards} Goodbye!'

# %%
#| hide
