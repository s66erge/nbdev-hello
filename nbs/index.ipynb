# %%
#| hide
from nbdev_hello.core import *

# %% [markdown]
# # nbdev-hello
#
# > testing nbdev

# %% [markdown]
# This file will become your README and also the index of your documentation.

# %% [markdown]
# ## Developer Guide

# %% [markdown]
# If you are new to using `nbdev` here are some pointers to get you started.

# %% [markdown]
# ### Install nbdev_hello in Development mode

# %% [markdown]
# ```sh
# # make sure nbdev_hello package is installed in development mode
# $ pip install -e .
#
# # make changes under nbs/ directory
# # ...
#
# # compile to have changes apply to nbdev_hello
# $ nbdev_prepare
# ```

# %% [markdown]
# ## Usage

# %% [markdown]
# ### Installation

# %% [markdown]
# Install latest from the GitHub [repository][repo]:
#
# ```sh
# $ pip install git+https://github.com/s66erge/nbdev-hello.git
# ```
#
# or from [conda][conda]
#
# ```sh
# $ conda install -c s66erge nbdev_hello
# ```
#
# or from [pypi][pypi]
#
#
# ```sh
# $ pip install nbdev_hello
# ```
#
#
# [repo]: https://github.com/s66erge/nbdev-hello
# [docs]: https://s66erge.github.io/nbdev-hello/
# [pypi]: https://pypi.org/project/nbdev-hello/
# [conda]: https://anaconda.org/s66erge/nbdev-hello

# %% [markdown]
# ### Documentation

# %% [markdown]
# Documentation can be found hosted on this GitHub [repository][repo]'s [pages][docs]. Additionally you can find package manager specific guidelines on [conda][conda] and [pypi][pypi] respectively.
#
# [repo]: https://github.com/s66erge/nbdev-hello
# [docs]: https://s66erge.github.io/nbdev-hello/
# [pypi]: https://pypi.org/project/nbdev-hello/
# [conda]: https://anaconda.org/s66erge/nbdev-hello

# %% [markdown]
# ## How to use

# %% [markdown]
# Fill me in please! Don't forget code examples:

# %%
1+1
# Out:
# 2
